# %% [markdown]
# # Homework_Week 5 - 王梓旭 - 2201212423

# %% [markdown]
# ### Given H1.xls, extract all the hyperlinks into one column, as illustrated in New_H1.xls.

# %%
# 导入必要的包

import pandas as pd
import re
from openpyxl import load_workbook

# %%
# 对于那些没有设置超链接的，只是用网址链接形式（同文字混杂）呈现，我们需要提取网址并将其制作为超链接

def convert_text_to_hyperlink(text):
    # 使用正则表达式查找文本中的网址
    urls = re.findall(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', text)
    
    # 如果找到了网址，创建超链接
    if urls:
        hyperlink = f'=HYPERLINK("{urls[0]}","{urls[0]}")'
        return hyperlink
    
    # 若没找到网址，则是文本（例如“Python作业”）作为超链接描述的情况，先返回"0"，再做处理
    return str(0)

# %%
# 读取Excel文件
file_path = 'H1.xls'
df = pd.read_excel(file_path)

# 转换文本为超链接
df2 = pd.DataFrame()
df2["Hyperlink"] = df['在线文档地址（必填）'].apply(convert_text_to_hyperlink)
mask = df2['Hyperlink'] == '0'
df2 = df2[~mask]

# %%
df2
# Out:
#                                             Hyperlink
# 1   =HYPERLINK("https://docs.qq.com/doc/DYUJhR2pXS...
# 2   =HYPERLINK("https://docs.qq.com/doc/DVnpOTGZ5d...
# 3   =HYPERLINK("https://docs.qq.com/doc/DTGtMVUNwW...
# 6   =HYPERLINK("https://docs.qq.com/pdf/DWnRLc0VFd...
# 8   =HYPERLINK("https://docs.qq.com/doc/DQVFTd0pXd...
# 9   =HYPERLINK("https://docs.qq.com/pdf/DS2VaS3NIT...
# 10  =HYPERLINK("https://docs.qq.com/pdf/DWE9kcHRWe...
# 11  =HYPERLINK("https://docs.qq.com/doc/DTlhXRXpYa...
# 12  =HYPERLINK("https://docs.qq.com/doc/DZUFtUHlMV...
# 13  =HYPERLINK("https://docs.qq.com/pdf/DR2pqUmpud...
# 14  =HYPERLINK("https://docs.qq.com/doc/DSGZqSk1IY...
# 15  =HYPERLINK("https://docs.qq.com/pdf/DYVZtU1lWR...
# 16  =HYPERLINK("https://docs.qq.com/doc/p/d6db28e0...
# 17  =HYPERLINK("https://docs.qq.com/pdf/DQ1V2U0dOd...
# 18  =HYPERLINK("https://docs.qq.com/doc/DUklKeW5Gd...
# 19  =HYPERLINK("https://kdocs.cn/l/cnfQUoNNifmI","...
# 20  =HYPERLINK("https://docs.qq.com/doc/DUk9Zbkhie...
# 21  =HYPERLINK("https://docs.qq.com/doc/DT2NsUUVSb...
# 22  =HYPERLINK("https://docs.qq.com/doc/DVWFXQWNVR...
# 23  =HYPERLINK("https://docs.qq.com/doc/DS1JLRFFmd...
# 25  =HYPERLINK("https://docs.qq.com/doc/DQkpDRGRqV...
# 26  =HYPERLINK("https://docs.qq.com/doc/DV2thVVFUT...
# 27  =HYPERLINK("https://docs.qq.com/doc/DVGN5bHVqW...
# 28  =HYPERLINK("https://docs.qq.com/doc/DQU1aUnRKR...
# 29  =HYPERLINK("https://disk.pku.edu.cn:443/link/E...
# 30  =HYPERLINK("https://docs.qq.com/doc/DVmVzcnh3V...
# 31  =HYPERLINK("https://docs.qq.com/pdf/DYXJPaXVzV...
# 32  =HYPERLINK("https://docs.qq.com/doc/DTnR1TWdYe...
# 33  =HYPERLINK("https://docs.qq.com/doc/DUmZ5cGNnV...
# 34  =HYPERLINK("https://docs.qq.com/pdf/DZG9JVmJxR...
# 35  =HYPERLINK("https://disk.pku.edu.cn:443/link/1...
# 36  =HYPERLINK("https://docs.qq.com/doc/DZEpWQ2lzS...
# 37  =HYPERLINK("https://docs.qq.com/pdf/DUENPSmtMb...
# 38  =HYPERLINK("https://docs.qq.com/pdf/DS1hTcGdhb...
# 39  =HYPERLINK("https://docs.qq.com/doc/DR0lmaXJ6c...
# 40  =HYPERLINK("https://docs.qq.com/pdf/DYlFZZ2VxY...
# 41  =HYPERLINK("https://docs.qq.com/doc/DTnFyTmdja...
# 42  =HYPERLINK("https://docs.qq.com/doc/DVllDcU9LT...
# 43  =HYPERLINK("https://docs.qq.com/pdf/DTW1wQ0JJY...
# 44  =HYPERLINK("https://docs.qq.com/doc/DUnZjRVN1Z...
# 45  =HYPERLINK("https://docs.qq.com/doc/DRU9leUl3S...
# 46  =HYPERLINK("https://docs.qq.com/doc/DWWdXc1Vpc...
# 47  =HYPERLINK("https://docs.qq.com/doc/DYm9xamRNR...
# 48  =HYPERLINK("https://docs.qq.com/pdf/DWE1lbUpyc...
# 49  =HYPERLINK("https://docs.qq.com/doc/DWVBNS3Nqd...
# 50  =HYPERLINK("https://shimo.im/docs/dJDjG83jYrdj...
# 51  =HYPERLINK("https://github.com/XinranGuo/2021_...
# 52  =HYPERLINK("https://docs.qq.com/doc/DQVlnb014e...
# 53  =HYPERLINK("https://docs.qq.com/doc/DUER5cEpkT...
# 54  =HYPERLINK("https://docs.qq.com/doc/DR1BwQWtsW...

# %%
# 如果在Excel中，某些文本（例如“Python作业”）作为超链接的描述，并且背后有一个实际的网址链接
# 那么我们需要用如下的方法来提取这些链接

def extract_hyperlinks_from_excel(file_path):
    wb = load_workbook(filename=file_path)
    sheet = wb.active

    hyperlinks = []

    for row in sheet.iter_rows():
        for cell in row:
            if cell.hyperlink:
                hyperlinks.append({
                    'text': cell.value,
                    'url': cell.hyperlink.target,
                    'source': file_path
                })

    return hyperlinks

# 使用函数提取超链接

file_path = 'H1.xlsx'  # 文件格式为xlsx，因为extract_hyperlinks_from_excel只接受.xlsx格式，.xls太老了
urls = [] # 存放链接地址
hyperlinks_data = extract_hyperlinks_from_excel(file_path)
for link in hyperlinks_data:
    urls.append(link['url'])

formatted_hyperlinks = [f'=HYPERLINK("{url}","{url}")' for url in urls]

df3 = pd.DataFrame({
    'Hyperlink': formatted_hyperlinks
})

# %%
df3
# Out:
#                                            Hyperlink
# 0  =HYPERLINK("https://docs.qq.com/doc/DWkh2R2JFe...
# 1  =HYPERLINK("https://docs.qq.com/doc/DWFJpYWJZV...
# 2  =HYPERLINK("https://docs.qq.com/doc/DSW9NWmhZW...
# 3  =HYPERLINK("https://docs.qq.com/doc/DZG1PaXJye...
# 4  =HYPERLINK("https://kdocs.cn/l/cnfQUoNNifmI%5b...
# 5  =HYPERLINK("https://docs.qq.com/doc/DSVdZTmptc...
# 6  =HYPERLINK("https://shimo.im/docs/dJDjG83jYrdj...
# 7  =HYPERLINK("https://github.com/XinranGuo/2021_...

# %%
df_save = pd.concat([df2, df3]).drop_duplicates().reset_index(drop=True)
df_save
# Out:
#                                             Hyperlink
# 0   =HYPERLINK("https://docs.qq.com/doc/DYUJhR2pXS...
# 1   =HYPERLINK("https://docs.qq.com/doc/DVnpOTGZ5d...
# 2   =HYPERLINK("https://docs.qq.com/doc/DTGtMVUNwW...
# 3   =HYPERLINK("https://docs.qq.com/pdf/DWnRLc0VFd...
# 4   =HYPERLINK("https://docs.qq.com/doc/DQVFTd0pXd...
# 5   =HYPERLINK("https://docs.qq.com/pdf/DS2VaS3NIT...
# 6   =HYPERLINK("https://docs.qq.com/pdf/DWE9kcHRWe...
# 7   =HYPERLINK("https://docs.qq.com/doc/DTlhXRXpYa...
# 8   =HYPERLINK("https://docs.qq.com/doc/DZUFtUHlMV...
# 9   =HYPERLINK("https://docs.qq.com/pdf/DR2pqUmpud...
# 10  =HYPERLINK("https://docs.qq.com/doc/DSGZqSk1IY...
# 11  =HYPERLINK("https://docs.qq.com/pdf/DYVZtU1lWR...
# 12  =HYPERLINK("https://docs.qq.com/doc/p/d6db28e0...
# 13  =HYPERLINK("https://docs.qq.com/pdf/DQ1V2U0dOd...
# 14  =HYPERLINK("https://docs.qq.com/doc/DUklKeW5Gd...
# 15  =HYPERLINK("https://kdocs.cn/l/cnfQUoNNifmI","...
# 16  =HYPERLINK("https://docs.qq.com/doc/DUk9Zbkhie...
# 17  =HYPERLINK("https://docs.qq.com/doc/DT2NsUUVSb...
# 18  =HYPERLINK("https://docs.qq.com/doc/DVWFXQWNVR...
# 19  =HYPERLINK("https://docs.qq.com/doc/DS1JLRFFmd...
# 20  =HYPERLINK("https://docs.qq.com/doc/DQkpDRGRqV...
# 21  =HYPERLINK("https://docs.qq.com/doc/DV2thVVFUT...
# 22  =HYPERLINK("https://docs.qq.com/doc/DVGN5bHVqW...
# 23  =HYPERLINK("https://docs.qq.com/doc/DQU1aUnRKR...
# 24  =HYPERLINK("https://disk.pku.edu.cn:443/link/E...
# 25  =HYPERLINK("https://docs.qq.com/doc/DVmVzcnh3V...
# 26  =HYPERLINK("https://docs.qq.com/pdf/DYXJPaXVzV...
# 27  =HYPERLINK("https://docs.qq.com/doc/DTnR1TWdYe...
# 28  =HYPERLINK("https://docs.qq.com/doc/DUmZ5cGNnV...
# 29  =HYPERLINK("https://docs.qq.com/pdf/DZG9JVmJxR...
# 30  =HYPERLINK("https://disk.pku.edu.cn:443/link/1...
# 31  =HYPERLINK("https://docs.qq.com/doc/DZEpWQ2lzS...
# 32  =HYPERLINK("https://docs.qq.com/pdf/DUENPSmtMb...
# 33  =HYPERLINK("https://docs.qq.com/pdf/DS1hTcGdhb...
# 34  =HYPERLINK("https://docs.qq.com/doc/DR0lmaXJ6c...
# 35  =HYPERLINK("https://docs.qq.com/pdf/DYlFZZ2VxY...
# 36  =HYPERLINK("https://docs.qq.com/doc/DTnFyTmdja...
# 37  =HYPERLINK("https://docs.qq.com/doc/DVllDcU9LT...
# 38  =HYPERLINK("https://docs.qq.com/pdf/DTW1wQ0JJY...
# 39  =HYPERLINK("https://docs.qq.com/doc/DUnZjRVN1Z...
# 40  =HYPERLINK("https://docs.qq.com/doc/DRU9leUl3S...
# 41  =HYPERLINK("https://docs.qq.com/doc/DWWdXc1Vpc...
# 42  =HYPERLINK("https://docs.qq.com/doc/DYm9xamRNR...
# 43  =HYPERLINK("https://docs.qq.com/pdf/DWE1lbUpyc...
# 44  =HYPERLINK("https://docs.qq.com/doc/DWVBNS3Nqd...
# 45  =HYPERLINK("https://shimo.im/docs/dJDjG83jYrdj...
# 46  =HYPERLINK("https://github.com/XinranGuo/2021_...
# 47  =HYPERLINK("https://docs.qq.com/doc/DQVlnb014e...
# 48  =HYPERLINK("https://docs.qq.com/doc/DUER5cEpkT...
# 49  =HYPERLINK("https://docs.qq.com/doc/DR1BwQWtsW...
# 50  =HYPERLINK("https://docs.qq.com/doc/DWkh2R2JFe...
# 51  =HYPERLINK("https://docs.qq.com/doc/DWFJpYWJZV...
# 52  =HYPERLINK("https://docs.qq.com/doc/DSW9NWmhZW...
# 53  =HYPERLINK("https://docs.qq.com/doc/DZG1PaXJye...
# 54  =HYPERLINK("https://kdocs.cn/l/cnfQUoNNifmI%5b...
# 55  =HYPERLINK("https://docs.qq.com/doc/DSVdZTmptc...

# %%
# 保存修改后的Excel文件
new_file_path = 'New_H1.xls'
df_save.to_excel(new_file_path, index=False, engine='openpyxl')

print(f"提取全部超链接的Excel文件已保存到 {new_file_path}.")
# Out:
# 提取全部超链接的Excel文件已保存到 New_H1.xls.
